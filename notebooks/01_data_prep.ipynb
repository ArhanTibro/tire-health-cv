# %%
# 01 - Data Preparation
#Checks class balance, then splits `data/softcom_dataset/` into `train/val/test` at `data/processed/`.
import sys
sys.path.insert(0, '..')

from src.data.split_dataset import check_dataset, split_data

# %%
# Step 1: Check dataset balance
counts = check_dataset('../data/softcom_dataset')
# Out:
# Dataset check:
# healthy : 167 images
# low_tread : 51 images
# sidewall_damaged : 8 images   <- low, may need more images
# uneven_wear : 21 images
# zero_tread : 38 images
# Total: 285 images

# %%
# Step 2: Run the split
split_data('../data/softcom_dataset', '../data/processed')
# Out:
# healthy - train: 116 val: 25 test: 26
# low_tread - train: 35 val: 7 test: 9
# sidewall_damaged - train: 5 val: 1 test: 2
# uneven_wear - train: 14 val: 3 test: 4
# zero_tread - train: 26 val: 5 test: 7

# %%
# Step 3: Confirm the output
import os

for split_name in ['train', 'val', 'test']:
    print('---', split_name, '---')
    for class_name in counts:
        folder = os.path.join('../data/processed', split_name, class_name)
        if os.path.isdir(folder):
            print(class_name, ':', len(os.listdir(folder)))
# Out:
# --- train ---
# healthy : 116
# low_tread : 35
# sidewall_damaged : 5
# uneven_wear : 14
# zero_tread : 26
# --- val ---
# healthy : 25
# low_tread : 7
# sidewall_damaged : 1
# uneven_wear : 3
# zero_tread : 5
# --- test ---
# healthy : 26
# low_tread : 9
# sidewall_damaged : 2
# uneven_wear : 4
# zero_tread : 7
